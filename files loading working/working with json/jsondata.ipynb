# %% [markdown]
# # WORKING WITH JSON

# %% [markdown]
# ## loading

# %%
import pandas as pd 
from io import  StringIO

# %%
path=r"D:\data scinece lab projects\files loading working\working with json\train.json"

# %%
data = pd.read_json(path)

# %%
data.to_csv("recicpe.csv",index=False)

# %%
datanew=pd.read_csv(r"D:\data scinece lab projects\files loading working\working with json\recicpe.csv",chunksize=15000)

# %%
for chunk in datanew:
    print(chunk.size)
# Out:
# 45000
# 45000
# 29322

# %%
import pandas as pd

path = r"D:\data scinece lab projects\files loading working\working with json\train.json"

# Put these together so they always run as a pair
try:
    # 1. Initialize the reader
    data_reader = pd.read_json(path, lines=True, chunksize=5000)

    # 2. Iterate immediately
    for chunk in data_reader:
        print(f"Processing chunk with shape: {chunk.shape}")
        # Your ML code or database storage goes here
        
except ValueError as e:
    print(f"Error: {e}")
    print("Check if your file is actually in JSON Lines format (no [ ] brackets).")
# Out:
# Error: Expected object or value
# Check if your file is actually in JSON Lines format (no [ ] brackets).

# %%
import json
import pandas as pd
import os


# We use 'lines=True' because we are reading the NEW fixed file
data_reader = pd.read_json(output_path, lines=True, chunksize=5000)


for chunk in data_reader:
    print(f"Shape: {chunk}")
# Out:
# Shape:          id      cuisine                                        ingredients
# 0     10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1     25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2     20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3     22213       indian                [water, vegetable oil, wheat, salt]
# 4     13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...     ...          ...                                                ...
# 4995  29350      mexican  [cream cheese, chili, corn tortilla chips, shr...
# 4996  17095     japanese  [shoga, beef, scallions, soy sauce, base, onio...
# 4997   7737      chinese  [bacon, garlic chives, squash, cracked black p...
# 4998  41431      british  [pepper, vegetable oil, all-purpose flour, col...
# 4999  29119  southern_us  [yellow corn meal, vegetable oil, ground cayen...
#
# [5000 rows x 3 columns]
# Shape:          id      cuisine                                        ingredients
# 5000  24549     moroccan                    [mint sprigs, sugar, green tea]
# 5001  40063     japanese  [soy sauce, katsuo bushi, sake, sesame seeds, ...
# 5002   2562      spanish           [scallions, spanish chorizo, rice pilaf]
# 5003  34100  southern_us  [fresh chives, crushed red pepper, pepper, sou...
# 5004  43641       korean  [sugar, honey, sesame oil, Gochujang base, egg...
# ...     ...          ...                                                ...
# 9995  42428  southern_us  [kosher salt, vegetable oil, beer, large shrim...
# 9996  29988      italian  [pitted kalamata olives, feta cheese crumbles,...
# 9997  37477      italian  [orange, cured meats, extra-virgin olive oil, ...
# 9998  45615      mexican  [avocado, olive oil, garlic, cumin, plain yogu...
# 9999  41152      mexican  [fresh cilantro, chili powder, garlic salt, co...
#
# [5000 rows x 3 columns]
# Shape:           id   cuisine                                        ingredients
# 10000  24680   italian  [romano cheese, salt, reduced fat milk, walnut...
# 10001  41692    indian  [urad dal, oil, fenugreek seeds, salt, poha, r...
# 10002   7101   italian  [kahlúa, coffee granules, unsweetened cocoa po...
# 10003  37781   italian  [sage leaves, kosher salt, ground black pepper...
# 10004  35540   mexican  [pepper, salsa, cilantro, corn tortillas, vege...
# ...      ...       ...                                                ...
# 14995  28931   italian  [chopped fresh thyme, soppressata, olive oil, ...
# 14996   7144  jamaican  [scallions, coconut milk, red chili peppers, g...
# 14997    255   italian  [ground nutmeg, salt, tagliatelle, garlic powd...
# 14998  13340  moroccan  [orange liqueur, ginger ale, pomegranate juice...
# 14999    780    french  [butter, lemon pepper, pork tenderloin, dijon ...
#
# [5000 rows x 3 columns]
# Shape:           id       cuisine                                        ingredients
# 15000  48491       italian  [white wine, garlic cloves, crushed red pepper...
# 15001  40865       italian  [olive oil, chopped fresh chives, all-purpose ...
# 15002  25534       mexican  [bell pepper, oil, purple onion, boneless skin...
# 15003  39805  cajun_creole  [sugar, vegetable oil, stewed tomatoes, rice, ...
# 15004    802   southern_us  [cooked ham, pimentos, celery ribs, sweet onio...
# ...      ...           ...                                                ...
# 19995  31538        french  [French lentils, celery root, minced garlic, c...
# 19996   1893   southern_us  [firmly packed brown sugar, ground ginger, gro...
# 19997  30616       chinese  [sugar pea, pork tenderloin, red pepper flakes...
# 19998  44134      moroccan  [tumeric, ground cumin, ground cinnamon, allsp...
# 19999  38071       mexican  [yellow squash, roma tomatoes, cilantro, grate...
#
# [5000 rows x 3 columns]
# Shape:           id      cuisine                                        ingredients
# 20000   4110     moroccan  [saffron threads, quinces, red currant jelly, ...
# 20001  47868      mexican  [cayenne, ground allspice, canola oil, jack ch...
# 20002   5330  southern_us  [mayonaise, garlic powder, salt, cornmeal, mea...
# 20003  21766  southern_us  [bacon slices, cooked chicken, bread slices, m...
# 20004  22144      spanish  [tomato paste, black pepper, spanish onion, ga...
# ...      ...          ...                                                ...
# 24995  20514      chinese  [sliced carrots, hot chili sauce, shrimp, grou...
# 24996  30037     filipino  [butter, shrimp, pepper, salt, hot red pepper ...
# 24997  31397     japanese  [fennel seeds, fresh curry leaves, sesame oil,...
# 24998  10242      mexican  [water, red wine vinegar, salt, oregano, pico ...
# 24999  36176      mexican  [kosher salt, jalapeno chilies, garlic, corn b...
#
# [5000 rows x 3 columns]
# Shape:           id   cuisine                                        ingredients
# 25000  28642   mexican  [cotija, cracker crumbs, salt, chipotles in ad...
# 25001  27953  japanese  [sugar pea, all-purpose flour, vegetable oil, ...
# 25002  20576  japanese  [eggs, mirin, choy sum, mixed spice, sesame oi...
# 25003  35175   italian  [roasted red peppers, black olives, dried oreg...
# 25004  29239   mexican  [sugar, butter, lemon juice, graham cracker cr...
# ...      ...       ...                                                ...
# 29995  31137  japanese  [udon, peas, hoisin sauce, shallots, toasted s...
# 29996  39807  japanese  [avocado, carrots, nori, rice vinegar, tuna, s...
# 29997  43466   mexican  [queso fresco, corn tortillas, jalapeno chilie...
# 29998  47351    indian  [water, salt, chopped cilantro fresh, red chil...
# 29999  37292      thai  [dried apricot, vegetable oil, unsweetened coc...
#
# [5000 rows x 3 columns]
# Shape:           id      cuisine                                        ingredients
# 30000  24349      italian  [semolina, salt, powdered sugar, large eggs, o...
# 30001  14560      italian  [salt, romano cheese, dried oregano, ground bl...
# 30002  49682     filipino  [eggs, calamansi juice, sugar, salt, powdered ...
# 30003  25905  southern_us  [condensed cream of mushroom soup, crawfish, o...
# 30004  12284      italian  [genoa salami, large eggs, onions, swiss chard...
# ...      ...          ...                                                ...
# 34995  23262   vietnamese  [black pepper, garlic sauce, canola oil, fish ...
# 34996  14477      italian  [grated parmesan cheese, garlic powder, refrig...
# 34997  30531       indian  [curry powder, carrots, onions, yellow mustard...
# 34998  12346       french  [kosher salt, shallots, fresh lemon juice, bib...
# 34999  15987      italian  [roma tomatoes, pesto sauce, prepared pizza cr...
#
# [5000 rows x 3 columns]
# Shape:           id       cuisine                                        ingredients
# 35000   9492  cajun_creole  [butter, Sargento® Artisan Blends® Shredded Pa...
# 35001  37844        indian  [large eggs, all-purpose flour, ground turmeri...
# 35002  24259   southern_us  [unsalted butter, fresh lemon juice, sugar, sa...
# 35003  34231        indian  [tortillas, greek yogurt, purple onion, tandoo...
# 35004  19130       mexican  [pepper, flour tortillas, salsa, iceberg lettu...
# ...      ...           ...                                                ...
# 39769  29109         irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462       italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238         irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882       chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362       mexican  [green chile, jalapeno chilies, onions, ground...
#
# [4774 rows x 3 columns]

# %%
data1=pd.read_json(output_path, lines=True,nrows=500 ,dtype=object).dtypes
data1.dtype
# Out:
# dtype('O')

# %%
data1
# Out:
# id             object
# cuisine        object
# ingredients    object
# dtype: object

# %%
dataa=pd.read_json(r"D:\data scinece lab projects\files loading working\working with json\train_fixed.jsonl",lines=True,nrows=500)

dataa
# Out:
#         id      cuisine                                        ingredients
# 0    10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1    25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2    20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3    22213       indian                [water, vegetable oil, wheat, salt]
# 4    13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ..     ...          ...                                                ...
# 495   1121      chinese  [ground pepper, garlic, safflower oil, green o...
# 496  18376      italian  [penne, garlic, eggplant, lemon juice, olive o...
# 497  17815      italian  [cold water, dry white wine, fish fillets, cho...
# 498  32878  southern_us  [water, cajun seasoning, yellow onion, shrimp,...
# 499  24410      british  [mint, large eggs, heavy cream, berries, groun...
#
# [500 rows x 3 columns]

# %%
dataa=pd.read_json(r"D:\data scinece lab projects\files loading working\working with json\train_fixed.jsonl",lines=True,chunksize=125)


## how to print first chunk 
firstch=next(dataa)

print (firstch)


for i in  dataa:
    print(i.shape)
# Out:
#         id      cuisine                                        ingredients
# 0    10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1    25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2    20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3    22213       indian                [water, vegetable oil, wheat, salt]
# 4    13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ..     ...          ...                                                ...
# 120  20955      italian  [cold water, sugar, butter, chocolate morsels,...
# 121  45776      italian  [pinenuts, zucchini, baby carrots, fresh basil...
# 122   6043     jamaican  [tomato sauce, ground black pepper, garlic, sc...
# 123    336      mexican  [water, condensed cream of mushroom soup, cond...
# 124  25751     japanese  [pepper, panko breadcrumbs, plain flour, oil, ...
#
# [125 rows x 3 columns]
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (125, 3)
# (24, 3)
