# %%
## variance and mean 
import numpy as np

data=[28,30,32,34,36]


x=0
n=0
for i in range (len(data)):
    x=x+data[i] 
n=i+1

mean=x/n

# %%
var = sum_sq_x/n - 1        # ← this is what you executed

# %%
print(" mean:",mean)
print ("var:",var)
# Out:
#  mean: 32.0
# var: 7.0
