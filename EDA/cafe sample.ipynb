# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sb

# %%
path='D:\data scinece lab projects\dirty_cafe_sales - dirty_cafe_sales.csv'
data=pd.read_csv(path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Malik\AppData\Local\Temp\ipykernel_17504\2636549402.py:1: SyntaxWarning: invalid escape sequence '\d'
#   path='D:\data scinece lab projects\dirty_cafe_sales - dirty_cafe_sales.csv'

# %%
data.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2              2           4     Credit Card
# 1    TXN_4977031    Cake        4              3          12            Cash
# 2    TXN_4271903  Cookie        4              1       ERROR     Credit Card
# 3    TXN_7034554   Salad        2              5          10         UNKNOWN
# 4    TXN_3160411  Coffee        2              2           4  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
data.shape
# Out:
# (10000, 8)

# %%
data.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
data = pd.read_csv(path)

for col in data.columns:
    null_indices = data[col][data[col].isnull()].index
    if len(null_indices) > 0:
        print(f"{col}: {list(null_indices)}")
# Out:
# Item: [8, 30, 61, 72, 89, 100, 151, 168, 197, 203, 247, 269, 289, 311, 334, 356, 362, 369, 388, 442, 482, 523, 535, 605, 647, 663, 699, 759, 769, 771, 806, 815, 818, 877, 880, 901, 947, 972, 975, 990, 991, 1019, 1028, 1099, 1149, 1186, 1198, 1213, 1229, 1238, 1282, 1296, 1316, 1364, 1384, 1386, 1401, 1434, 1451, 1522, 1571, 1574, 1589, 1614, 1615, 1641, 1678, 1725, 1733, 1753, 1761, 1790, 1796, 1808, 1913, 1919, 2002, 2015, 2107, 2150, 2159, 2218, 2226, 2328, 2371, 2382, 2383, 2388, 2391, 2415, 2433, 2462, 2483, 2487, 2563, 2583, 2596, 2610, 2712, 2817, 2904, 2914, 2916, 2934, 2976, 3059, 3067, 3172, 3227, 3236, 3239, 3243, 3373, 3375, 3378, 3396, 3404, 3427, 3479, 3487, 3518, 3526, 3545, 3609, 3643, 3677, 3679, 3690, 3759, 3774, 3796, 3817, 3824, 3877, 3878, 3900, 3913, 3964, 3991, 4003, 4018, 4075, 4086, 4119, 4211, 4233, 4255, 4269, 4279, 4303, 4364, 4373, 4430, 4445, 4456, 4528, 4568, 4665, 4764, 4807, 4831, 4853, 4915, 4927, 4947, 4995, 5014, 5045, 5125, 5133, 5135, 5193, 5202, 
# ...

# %%
data['Item'].drop_duplicates
# Out:
# <bound method Series.drop_duplicates of 0         Coffee
# 1           Cake
# 2         Cookie
# 3          Salad
# 4         Coffee
#           ...
# 9995      Coffee
# 9996         NaN
# 9997      Coffee
# 9998      Cookie
# 9999    Sandwich
# Name: Item, Length: 10000, dtype: object>

# %%
for col in data.select_dtypes(include=['object']).columns:
    data[col] = data[col].astype('category')

# %%
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2              2           4
# 9996    TXN_9659401       NaN        3            NaN           3
# 9997    TXN_5255387    Coffee        4              2           8
# 9998    TXN_7695629    Cookie        3            NaN           3
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data['Item'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data['Item'].dtype()
#
# TypeError: 'CategoricalDtype' object is not callable

# %%
data=data.dropna()

# %%
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN              4           4
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data[['Location', 'Total Spent','Item']] = data[['Location', 'Total Spent','Item']].replace(['UNKNOWN', 'ERROR','UNKNOWN'], np.nan)

data = data.dropna(subset=['Location', 'Total Spent','Item'])
print(data['Location'].unique())
print(data['Total Spent'].unique())
print(data['Item'].unique())
# Out:
# ['Takeaway', 'In-store']
# Categories (2, object): ['In-store', 'Takeaway']
# ['4', '12', '25', '8', '15', ..., '1', '9', '7.5', '4.5', '1.5']
# Length: 17
# Categories (17, object): ['1', '1.5', '10', '12', ..., '6', '7.5', '8', '9']
# ['Coffee', 'Cake', 'Salad', 'Sandwich', 'Juice', 'Smoothie', 'Cookie', 'Tea']
# Categories (8, object): ['Cake', 'Coffee', 'Cookie', 'Juice', 'Salad', 'Sandwich', 'Smoothie', 'Tea']
# C:\Users\Malik\AppData\Local\Temp\ipykernel_17504\1245300532.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   data[['Location', 'Total Spent','Item']] = data[['Location', 'Total Spent','Item']].replace(['UNKNOWN', 'ERROR','UNKNOWN'], np.nan)

# %%
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 4       TXN_3160411    Coffee        2              2           4
# 10      TXN_2548360     Salad        5              5          25
# 11      TXN_3051279  Sandwich        2              4           8
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN              4           4
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date      Itme
# 0        Credit Card  Takeaway       2023-09-08    Coffee
# ...
