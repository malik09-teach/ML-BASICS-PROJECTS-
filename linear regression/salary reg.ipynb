# %%
import numpy as pd

# %%
import kaggle
import pandas as pd
import os

# Define the Kaggle dataset path (AuthorName/DatasetName)
dataset_path = "ara001/salary-prediction-dataset"

# Download the dataset to the current working directory
kaggle.api.dataset_download_files(dataset_path, path=".", unzip=True)

# Load the downloaded CSV into Pandas
# (The CSV file name is usually 'Salary_dataset.csv' for the beginner dataset)
df = pd.read_csv("Salary_dataset.csv")

# Verify it loaded correctly
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kaggle
#       2 import pandas as pd
#       3 import os
#
# ModuleNotFoundError: No module named 'kaggle'
