# %% [markdown]
# # CSV DATA WORKING

# %%
import pandas as pd

# %% [markdown]
# ## FROM LOCAL MACHINE

# %%
# from loacal machine 

path='D:\data scinece lab projects\working on CSV\housing.csv'
data=pd.read_csv(path)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ## DATA TO CSV

# %%
import numpy as np

# Creating a fake dataset
data1 = {
    'Student_ID': [101, 102, 103, 104, 105, 106],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Math_Score': [85, np.nan, 78, 92, np.nan, 88],
    'Science_Score': [90, 82, 85, 77, 95, 89],
    'Attendance': ['95%', '80%', '75%', '90%', '60%', '85%'],
    'Status': ['Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass']
}


df_csv_in=pd.DataFrame(data1)

# %%
df_csv_in
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         101    Alice        85.0             90        95%   Pass
# 1         102      Bob         NaN             82        80%   Pass
# 2         103  Charlie        78.0             85        75%   Pass
# 3         104    David        92.0             77        90%   Pass
# 4         105      Eva         NaN             95        60%   Fail
# 5         106    Frank        88.0             89        85%   Pass

# %%
df_csv_in.to_csv('student.csv',index=False)

# %%
data2=pd.read_csv('D:\data scinece lab projects\working on CSV\student.csv')

# %%
data2
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         101    Alice        85.0             90        95%   Pass
# 1         102      Bob         NaN             82        80%   Pass
# 2         103  Charlie        78.0             85        75%   Pass
# 3         104    David        92.0             77        90%   Pass
# 4         105      Eva         NaN             95        60%   Fail
# 5         106    Frank        88.0             89        85%   Pass

# %% [markdown]
# ## FROM URL

# %%
URL="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

data3=pd.read_csv(URL)


'''ADVANCE METHOD
If the pandas block by any website then it will use the request formate 

Sometimes a website might block direct access from
 Pandas (to prevent bots). In those cases, you use the requests library to "pretend" 
to be a browser, and then use io to read the text.

"import pandas as pd
import requests
import io

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# 1. Fetch the content from the URL
response = requests.get(url)

# 2. Check if the request was successful
if response.status_status == 200:
    # 3. Use io.StringIO to convert the text content into a file-like object
    csv_data = io.StringIO(response.text)
    df = pd.read_csv(csv_data)
    
    print("Fetched via Requests:")
    print(df.info())
else:
    print("Failed to download file.")"

 '''


'''
When loading from URLs, you often encounter these three parameters:

Parameter              When to use it  
storage_options        If the URL requires an API key or User-Agent headers.
sep                    If the URL file uses tabs (\t) or semicolons (;) instead of commas.
compression            If the URL ends in .zip or .gz, Pandas can automatically unzip it if you set compression='infer'.



code 

df = pd.read_csv(
    "https://example.com/data.zip", 
    sep=',', 
    compression='zip', 
    encoding='utf-8'
)df = pd.read_csv(
    "https://example.com/data.zip", 
    sep=',', 
    compression='zip', 
    encoding='utf-8'
)



'''
# Out:
# '\nWhen loading from URLs, you often encounter these three parameters:\n\nParameter              When to use it  \nstorage_options        If the URL requires an API key or User-Agent headers.\nsep                    If the URL file uses tabs (\t) or semicolons (;) instead of commas.\ncompression            If the URL ends in .zip or .gz, Pandas can automatically unzip it if you set compression=\'infer\'.\n\n\n\ncode \n\ndf = pd.read_csv(\n    "https://example.com/data.zip", \n    sep=\',\', \n    compression=\'zip\', \n    encoding=\'utf-8\'\n)df = pd.read_csv(\n    "https://example.com/data.zip", \n    sep=\',\', \n    compression=\'zip\', \n    encoding=\'utf-8\'\n)\n\n\n\n'

# %%
data3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### FETCH DATA TO CSV FILE CONVERSION

# %%
# file conversion
data3.to_csv("EXP_IRS.csv",index=False)

# %% [markdown]
# # DATA EXPLORATION

# %%
data.head()# giving a head
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.tail() # giving the tail
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
data.info() #giving the information about the columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %%
data.describe() # giving us the diff parameters
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.shape # give us the mainly col and row no
# Out:
# (20640, 10)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # LOADING TSV

# %% [markdown]
# ## WITH NAMING TO THE UNDEFINE COLUMN

# %%
## how to handel  that is handel by on doing the add the "sep=/t"
## also add the r"............." it encode the string in the right formate 
## naming to the columns properly 

path=r"D:\data scinece lab projects\working on CSV\file.tsv"

data4=pd.read_csv(r"D:\data scinece lab projects\working on CSV\file.tsv",sep='\t',names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
data4.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %% [markdown]
# #  SAME COL NAME WITH SAME FUN CAN REPPALACE

# %%
# IN ABOVE THE USER ID AND THE S.NO HAVE SAME FUN 

data5=pd.read_csv("student.csv")
data5
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         101    Alice        85.0             90        95%   Pass
# 1         102      Bob         NaN             82        80%   Pass
# 2         103  Charlie        78.0             85        75%   Pass
# 3         104    David        92.0             77        90%   Pass
# 4         105      Eva         NaN             95        60%   Fail
# 5         106    Frank        88.0             89        85%   Pass

# %%
data5=pd.read_csv("student.csv",index_col='Student_ID')
data5
# Out:
#                Name  Math_Score  Science_Score Attendance Status
# Student_ID
# 101           Alice        85.0             90        95%   Pass
# 102             Bob         NaN             82        80%   Pass
# 103         Charlie        78.0             85        75%   Pass
# 104           David        92.0             77        90%   Pass
# 105             Eva         NaN             95        60%   Fail
# 106           Frank        88.0             89        85%   Pass

# %% [markdown]
# # THE USING COLUMNS IN DATA SET

# %%
data6=pd.read_csv("student.csv",usecols=['Student_ID','Attendance','Status'])
data6
# Out:
#    Student_ID Attendance Status
# 0         101        95%   Pass
# 1         102        80%   Pass
# 2         103        75%   Pass
# 3         104        90%   Pass
# 4         105        60%   Fail
# 5         106        85%   Pass

# %% [markdown]
# # SKIPPING ROW

# %%
# THE COL SERIES 

row_skips=pd.read_csv("student.csv",skiprows=[1,4])
row_skips
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         102      Bob         NaN             82        80%   Pass
# 1         103  Charlie        78.0             85        75%   Pass
# 2         105      Eva         NaN             95        60%   Fail
# 3         106    Frank        88.0             89        85%   Pass

# %%
# even number load
lambda_row_skip = pd.read_csv("housing.csv", skiprows=lambda x: x %2)
lambda_row_skip
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.22     37.86                21.0       7099.0          1106.0
# 1        -122.25     37.85                52.0       1274.0           235.0
# 2        -122.25     37.85                52.0        919.0           213.0
# 3        -122.25     37.84                52.0       3104.0           687.0
# 4        -122.25     37.84                52.0       3549.0           707.0
# ...          ...       ...                 ...          ...             ...
# 10315    -121.40     39.33                15.0       2655.0           493.0
# 10316    -121.53     39.19                27.0       2080.0           412.0
# 10317    -121.09     39.48                25.0       1665.0           374.0
# 10318    -121.22     39.43                17.0       2254.0           485.0
# 10319    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# #  SPECIFIC RANGE NO OF ROWS

# %%
data7=pd.read_csv("housing.csv",nrows=500)
data7
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 495    -122.25     37.86                52.0       4048.0           663.0
# 496    -122.26     37.85                52.0       3618.0           768.0
# 497    -122.27     37.85                52.0       4076.0           920.0
# 498    -122.27     37.85                47.0       2077.0           400.0
# 499    -122.27     37.85                50.0       1279.0           300.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %% [markdown]
# # ERRORS

# %% [markdown]
# ## encoding == uft-8 formate using their own data set uft formate   encoding= "latin-1"
#
# ## bad line remove the extra columns /val    error_bad_lines=False

# %% [markdown]
# # DATA TYPE PARMETER AND ITS CONVERSIONN

# %%
data7=pd.read_csv("housing.csv",nrows=500)
data7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           500 non-null    float64
#  1   latitude            500 non-null    float64
#  2   housing_median_age  500 non-null    float64
#  3   total_rooms         500 non-null    float64
#  4   total_bedrooms      498 non-null    float64
#  5   population          500 non-null    float64
#  6   households          500 non-null    float64
#  7   median_income       500 non-null    float64
#  8   median_house_value  500 non-null    float64
#  9   ocean_proximity     500 non-null    str
# dtypes: float64(9), str(1)
# memory usage: 43.1 KB

# %%
data7=pd.read_csv("housing.csv",nrows=500,dtype={'total_rooms':int})
data7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           500 non-null    float64
#  1   latitude            500 non-null    float64
#  2   housing_median_age  500 non-null    float64
#  3   total_rooms         500 non-null    int64
#  4   total_bedrooms      498 non-null    float64
#  5   population          500 non-null    float64
#  6   households          500 non-null    float64
#  7   median_income       500 non-null    float64
#  8   median_house_value  500 non-null    float64
#  9   ocean_proximity     500 non-null    str
# dtypes: float64(8), int64(1), str(1)
# memory usage: 43.1 KB

# %% [markdown]
# # RENAMING

# %%
def renname(name):
    if name == "NEAR BAY":
        return "yes located"
    else:
        return  name 
    

data7=pd.read_csv("housing.csv",nrows=500,converters={'ocean_proximity':renname})
data7
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -122.23     37.88                41.0        880.0           129.0
# 1      -122.22     37.86                21.0       7099.0          1106.0
# 2      -122.24     37.85                52.0       1467.0           190.0
# 3      -122.25     37.85                52.0       1274.0           235.0
# 4      -122.25     37.85                52.0       1627.0           280.0
# ..         ...       ...                 ...          ...             ...
# 495    -122.25     37.86                52.0       4048.0           663.0
# 496    -122.26     37.85                52.0       3618.0           768.0
# 497    -122.27     37.85                52.0       4076.0           920.0
# 498    -122.27     37.85                47.0       2077.0           400.0
# 499    -122.27     37.85                50.0       1279.0           300.0
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %% [markdown]
# # CHUNKING

# %%
DATA_CHUNKS=pd.read_csv("housing.csv",chunksize=5000)

# %%
for chunk in DATA_CHUNKS:
    print(chunk.size)
# Out:
# 50000
# 50000
# 50000
# 50000
# 6400

# %% [markdown]
# # NA vals

# %%
pd.read_csv("student.csv")
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         101    Alice        85.0             90        95%   Pass
# 1         102      Bob         NaN             82        80%   Pass
# 2         103  Charlie        78.0             85        75%   Pass
# 3         104    David        92.0             77        90%   Pass
# 4         105      Eva         NaN             95        60%   Fail
# 5         106    Frank        88.0             89        85%   Pass

# %%
pd.read_csv("student.csv",na_values=['Pass'])
# Out:
#    Student_ID     Name  Math_Score  Science_Score Attendance Status
# 0         101    Alice        85.0             90        95%    NaN
# 1         102      Bob         NaN             82        80%    NaN
# 2         103  Charlie        78.0             85        75%    NaN
# 3         104    David        92.0             77        90%    NaN
# 4         105      Eva         NaN             95        60%   Fail
# 5         106    Frank        88.0             89        85%    NaN
